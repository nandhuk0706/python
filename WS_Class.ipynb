# %% [markdown]
# <a href="https://colab.research.google.com/github/nandhuk0706/python/blob/main/WS_Class.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Python Api's**

# %% [markdown]
# # Request

# %%
! pip install requests

# %% [markdown]
# https://pypi.org/project/requests/

# %%
import requests
r = requests.get('https://pypi.org/project/requests/', auth=('user', 'pass'))
r.status_code
# Out:
# 200

# %%
r.headers['content-type']
# Out:
# 'application/json'

# %%
r.encoding
# Out:
# 'utf-8'

# %%
r.text
# Out:
# '{\n  "authenticated": true, \n  "user": "user"\n}\n'

# %%
r.json()
# Out:
# {'authenticated': True, 'user': 'user'}

# %% [markdown]
# **Beautifulsoup4**

# %% [markdown]
# > Beautiful Soup is a library that makes it easy to scrape information from web pages. It sits atop an HTML or XML parser, providing Pythonic idioms for iterating, searching, and modifying the parse tree.

# %% [markdown]
# https://pypi.org/project/beautifulsoup4/

# %%
! pip install beautifulsoup4

# %%
from bs4 import BeautifulSoup
soup = BeautifulSoup("<p>Some<b>bad<i>HTML")
print(soup.prettify())
# Out:
# <html>
#  <body>
#   <p>
#    Some
#    <b>
#     bad
#     <i>
#      HTML
#     </i>
#    </b>
#   </p>
#  </body>
# </html>

# %%
soup = BeautifulSoup("<tag1>Some<tag2/>bad<tag3>XML", "xml")
print(soup.prettify())
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <tag1>
#  Some
#  <tag2/>
#  bad
#  <tag3>
#   XML
#  </tag3>
# </tag1>

# %% [markdown]
# # Request-html

# %% [markdown]
# > This library intends to make parsing HTML (e.g. scraping the web) as simple and intuitive as possible.

# %% [markdown]
# https://pypi.org/project/requests-html/

# %%
! pip install requests_html

# %%
from requests_html import HTMLSession
session = HTMLSession()

r = session.get('https://python.org/')

# %%
r.status_code
# Out:
# 200

# %%
from requests_html import HTMLSession

# %%
s = HTMLSession()

# %%
query= input("Enter City : ")
# https://www.google.com/search?q=weather+Chennai
url =f'https://www.google.com/search?q=weather+{query}'
# https://www.google.com/search?q=wheather+chennai
# Out:
# Enter City : chennai

# %% [markdown]
# my user agent

# %%
#'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/109.0.0.0 Safari/537.36'

# %%
r=s.get(
    url,
    headers={'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/109.0.0.0 Safari/537.36'}
    )

# %%
r
# Out:
# <Response [200]>

# %%
temp = (r.html.find('title'))
temp
# Out:
# [<Element 'title' >]

# %%
temp = r.html.find('title',first = True)
temp
# Out:
# <Element 'title' >

# %%
temp = r.html.find('title',first = True).text
temp
# Out:
# 'weather chennai - Google Search'

# %%
help(r.html.find)

# %%
temp = r.html.find('span#wob_tm') # find('html_tag_name#id_value)
temp
# Out:
# [<Element 'span' class=('wob_t', 'q8U8x') id='wob_tm' style='display:inline'>]

# %%
temp = r.html.find('span#wob_tm',first = True).text
temp
#wob_tm
# Farenheit
# Out:
# '81'

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
temp = r.html.find('span#wob_tm',first = False)
temp
#wob_tm
# Farenheit
# Out:
# [<Element 'span' class=('wob_t', 'q8U8x') id='wob_tm' style='display:inline'>]

# %%
temp = r.html.find('span#wob_tm',first = True).text
temp
#wob_tm
# Farenheit
# Out:
# '81'

# %%
#wob_ttm
temp = r.html.find('span#wob_ttm',first = True).text
temp
# celsious
# Out:
# '27'

# %%
unit = (r.html.find('div.vk_bk.wob-unit span.wob_t',first=True)).text
#vk_bk wob-unit
# html_element.class_name html_element.class_name
unit
# Out:
# '°F'

# %%
desc = (r.html.find('div.VQF4g', first =True).find('span#wob_dc',first=True).text)
desc
# Out:
# 'Mostly cloudy'

# %%
print(query,temp,unit,desc)
# Out:
# chennai 27 °F Mostly cloudy

# %% [markdown]
# **Web Scraping**

# %% [markdown]
# request

# %%
! pip install requests

# %% [markdown]
# beautifulsoap

# %%
! pip install beautifulsoup4

# %%
! pip install bs4

# %%
! pip install requests_html

# %%
from requests_html import HTMLSession

# %%
from bs4 import BeautifulSoup
import requests

# %%
s = HTMLSession()

# %%
query= input("Enter City : ")
url =f'https://www.google.com/search?q=weather+{query}'
# Out:
# Enter City : chennai

# %%
res=s.get(url,headers={'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/109.0.0.0 Safari/537.36'})

# %%
res
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(res.text, 'html.parser')
#soup

# %%
#print(soup.prettify())

# %%
location = soup.select('#wob_loc')
location
# Out:
# [<div class="wob_loc q8U8x" id="wob_loc">Weather</div>]

# %%
help(soup.select)

# %%
location = soup.select('#wob_loc')[0]
location
# Out:
# <div class="wob_loc q8U8x" id="wob_loc">Weather</div>

# %%
location = soup.select('#wob_loc')[0].getText()
location
# Out:
# 'Weather'

# %%
location = soup.select('#wob_loc')[0].getText().strip()
location
# Out:
# 'Weather'

# %%
time = soup.select('#wob_dts')[0].getText().strip()
print(time)
# Out:
# Monday 10:00 AM

# %%
" <h1>Anu  </h1>  ".strip()
# Out:
# '<h1>Anu  </h1>'

# %%
info = soup.select('#wob_dc')[0].getText().strip()
info
# Out:
# 'Mostly cloudy'

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
weather = soup.select('#wob_tm')[0].getText().strip()
weather
# Out:
# '81'

# %% [markdown]
# ![image.png](data:image/png;base64,...)
